# %% [markdown]
# # **SEBIN JAMES**
# <br>
#
# ## GRIP MAY - Data Science and Business Analytics Internship
# <br>
#
# ### **TASK 2** - Exploratory Data Analysis - Sports
# <br>
#
# #### Exploratory Data Analysis
#
#
# Perform ‘Exploratory Data Analysis’ on dataset **Indian Premier League**
#
# ● As a sports analysts, find out the most successful teams, players and factors
# contributing win or loss of a team.
#
# ● Suggest teams or players a company should endorse for its products.

# %% [markdown]
# <br>
#
#
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %% [markdown]
# <br>
#
# ## Importing the Datasets
#
#
# <br>

# %%
# Importing all the datasets :
df_1 = pd.read_csv("C:/Users/Sebin James/Downloads/Indian Premier League/matches.csv")
df_2 = pd.read_csv("C:/Users/Sebin James/Downloads/Indian Premier League/deliveries.csv")

# %%
df_1.head(10)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
df_2.head(10)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 8         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 9         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
#
#    ball    batsman non_striker       bowler  is_super_over  ...  bye_runs  \
# ...

# %% [markdown]
# ## info

# %%
print(df_1.shape,"\n","\n", df_1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %% [markdown]
# # Looking for missing values in df_1

# %%
df_1.isnull().sum().sort_values(ascending=False)
# Out:
# umpire3            637
# city                 7
# player_of_match      4
# winner               4
# umpire1              2
# umpire2              2
# toss_winner          0
# season               0
# date                 0
# team1                0
# team2                0
# result               0
# toss_decision        0
# dl_applied           0
# win_by_runs          0
# win_by_wickets       0
# venue                0
# id                   0
# dtype: int64

# %% [markdown]
# \

# %%
df_1.umpire1.fillna("Unknown",inplace=True)
df_1.umpire2.fillna("Unknown",inplace=True)
df_1.umpire3.fillna("Unknown",inplace=True)
df_1.city.fillna("Unknown",inplace=True)
df_1.player_of_match.fillna("None",inplace=True)
df_1.winner.fillna("Draw",inplace=True)

# %%
df_1.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# umpire3            0
# dtype: int64

# %%
df_1["winner"].value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Delhi Capitals                  10
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Draw                             4
# Name: winner, dtype: int64

# %%
df_1["winner"].replace(to_replace = "Rising Pune Supergiant", value="Rising Pune Supergiants",inplace=True)

# %%
df_1["winner"].value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Rising Pune Supergiants         15
# Gujarat Lions                   13
# Pune Warriors                   12
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Draw                             4
# Name: winner, dtype: int64

# %%
df_1["team1"].replace(to_replace="Rising Pune Supergiant", value="Rising Pune Supergiants",inplace=True)
df_1["team2"].replace(to_replace="Rising Pune Supergiant", value="Rising Pune Supergiants",inplace=True)

# %%
df_1["city"].nunique()
# Out:
# 33

# %%
city = df_1.iloc[:,2].values

# %%
len(city)
# Out:
# 756

# %% [markdown]
# ## Analysing the Location of Matches

# %%
print(df_1["city"].value_counts())
fig_dims = (25, 10)
fig, ax1 = plt.subplots(figsize=fig_dims)
ax = sns.countplot("city",data=df_1,ax=ax1,palette="Paired")

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right",fontsize=15)
plt.xlabel("Cities",fontfamily="Times New Roman",fontsize=35,color="Purple")
plt.show()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Ahmedabad          12
# Centurion          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Ranchi              7
# Abu Dhabi           7
# Cuttack             7
# Port Elizabeth      7
# Unknown             7
# Cape Town           7
# Raipur              6
# Sharjah             6
# Kochi               5
# Kanpur              4
# Nagpur              3
# East London         3
# Kimberley           3
# Bloemfontein        2
# Name: city, dtype: int64
# ...

# %% [markdown]
# ## Analysis of Venues (Stadiums)

# %%
print(df_1["venue"].value_counts())
fig_dims = (25, 10)
fig, ax1 = plt.subplots(figsize=fig_dims)
ax = sns.countplot("venue",data=df_1,ax=ax1,palette="Accent")

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right",fontsize=15)
plt.xlabel("Stadiums",fontfamily="Sans Serif",fontsize=35,color="Purple")
plt.show()
# Out:
# Eden Gardens                                            77
# M Chinnaswamy Stadium                                   73
# Wankhede Stadium                                        73
# Feroz Shah Kotla                                        67
# Rajiv Gandhi International Stadium, Uppal               56
# MA Chidambaram Stadium, Chepauk                         49
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Maharashtra Cricket Association Stadium                 21
# Subrata Roy Sahara Stadium                              17
# Dr DY Patil Sports Academy                              17
# Kingsmead                                               15
# Punjab Cricket Association IS Bindra Stadium, Mohali    14
# SuperSport Park                                         12
# Sardar Patel Stadium, Motera                            12
# Brabourne Stadium                                       11
# ...

# %%
fig_dims = (50, 25)
fig, ax1 = plt.subplots(figsize=fig_dims)
ax = sns.countplot("venue",data=df_1,ax=ax1,hue="winner",palette="Paired")

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right",fontsize=27)
plt.xlabel("Stadiums",fontfamily="Times New Roman",fontsize=40,color="Purple")
plt.show()
# Out:
# C:\Users\Sebin James\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Most of the wins happened at Eden Gardens and Kolkata Night Riders were the winners the highest
#
# Then comes Wankhede Stadium with Mumbai Indians as winners most of the time

# %% [markdown]
# **Winner Count plot**

# %%
win_count = df_1.winner.value_counts().sort_values(ascending=False)
print(win_count)

fig_dims = (25, 10)
fig, ax1 = plt.subplots(figsize=fig_dims)
ax = sns.countplot(x="winner", data=df_1,ax=ax1)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right",fontsize=22)
plt.tight_layout()
plt.xlabel("IPL Teams",fontfamily="Times New Roman",fontsize=40,color="Red")
plt.show()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Rising Pune Supergiants         15
# Gujarat Lions                   13
# Pune Warriors                   12
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Draw                             4
# Name: winner, dtype: int64

# %% [markdown]
# ## Analysing Toss Decisions

# %%
df_1["toss_decision"].unique()
# Out:
# array(['field', 'bat'], dtype=object)

# %%
fig_dims = (12,6)
fig, ax1 = plt.subplots(figsize=fig_dims)
ax = sns.countplot(x="toss_decision", data=df_1,ax=ax1)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right",fontsize=22)
plt.tight_layout()
plt.xlabel("Fielding or Batting",fontfamily="Times New Roman",fontsize=35,color="Red")
plt.show()

# %%
#Fielding or Batting based on Teams
fig_dims = (25, 10)
fig, ax1 = plt.subplots(figsize=fig_dims)
ax = sns.countplot(x="toss_decision", data=df_1,ax=ax1,hue="toss_winner",palette="Set2",edgecolor=(0,0,0),linewidth=2)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right",fontsize=25)
plt.tight_layout()
plt.xlabel("Fielding or Batting based on Teams",fontfamily="Times New Roman",fontsize=40,color="Red")
plt.show()
#------------------------------------------------------------------------------------------------------------------------------------
# Fieding or Batting based on Season
fig_dims = (25, 10)
fig, ax1 = plt.subplots(figsize=fig_dims)
ax = sns.countplot(x="toss_decision", data=df_1,ax=ax1,hue="season",palette="Accent",edgecolor=(0,0,0),linewidth=2)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right",fontsize=22)
plt.tight_layout()
plt.xlabel("Fielding or Batting based on Season",fontfamily="Times New Roman",fontsize=40,color="Blue")
plt.show()

# %% [markdown]
# ##  $\color{Black}{\text{Does Winning the toss increase the chance of a team to win ?}}$

# %%
toss_dec = df_1.winner==df_1.toss_winner
toss_dec_count = toss_dec.value_counts()
toss_dec_count
# Out:
# True     388
# False    368
# dtype: int64

# %%
print((toss_dec_count/toss_dec.count())*100)
# Out:
# True     51.322751
# False    48.677249
# dtype: float64

# %%
plt.figure(figsize=(25,10))
plt.title('Does winning the toss increase the chances of winning the match?',fontsize= 20)
plt.pie(toss_dec_count,labels=toss_dec_count.index,autopct='%1.1f%%', startangle=180,);

# %%
df_1.corr()
# Out:
#                       id    season  dl_applied  win_by_runs  win_by_wickets
# id              1.000000  0.668304   -0.011658    -0.039403       -0.012239
# season          0.668304  1.000000   -0.001116    -0.037529       -0.009379
# dl_applied     -0.011658 -0.001116    1.000000    -0.016349       -0.011631
# win_by_runs    -0.039403 -0.037529   -0.016349     1.000000       -0.560420
# win_by_wickets -0.012239 -0.009379   -0.011631    -0.560420        1.000000

# %% [markdown]
# ## Analysing Man of the matches

# %%
Man_of_Match = df_1.groupby(df_1["player_of_match"]).player_of_match.agg("count").sort_values(ascending= False)
Man_of_Match = pd.DataFrame(Man_of_Match)
Man_of_Match.head()
# Out:
#                  player_of_match
# player_of_match
# CH Gayle                      21
# AB de Villiers                20
# RG Sharma                     17
# DA Warner                     17
# MS Dhoni                      17

# %%
Man_of_Match.tail()
# Out:
#                  player_of_match
# player_of_match
# MF Maharoof                    1
# MD Mishra                      1
# MA Starc                       1
# M Ur Rahman                    1
# A Chandila                     1

# %%
Man_of_Match=df_1.player_of_match.value_counts().sort_values(ascending=False)
Man_of_Match.to_frame().reset_index()
pd.DataFrame(Man_of_Match)
# Out:
#                 player_of_match
# CH Gayle                     21
# AB de Villiers               20
# RG Sharma                    17
# MS Dhoni                     17
# DA Warner                    17
# ...                         ...
# SW Billings                   1
# HH Gibbs                      1
# TA Boult                      1
# KK Cooper                     1
# SP Goswami                    1
#
# [227 rows x 1 columns]

# %% [markdown]
# ## Analysing Total Matches played,Total wins,Total Losses for each individual teams

# %%
teams = df_1.team1.append(df_1.team2)
teams_played = pd.DataFrame(teams)
teams_played.rename(columns={0:"Teams"},inplace=True)
teams_played
# Out:
#                            Teams
# 0            Sunrisers Hyderabad
# 1                 Mumbai Indians
# 2                  Gujarat Lions
# 3        Rising Pune Supergiants
# 4    Royal Challengers Bangalore
# ..                           ...
# 751               Mumbai Indians
# 752               Mumbai Indians
# 753               Delhi Capitals
# 754          Chennai Super Kings
# 755          Chennai Super Kings
#
# [1512 rows x 1 columns]

# %%
count=teams_played.value_counts().sort_values(ascending=False)
print(count)
fig_dims = (25,13)
fig, ax1 = plt.subplots(figsize=fig_dims)
ax = sns.countplot(x="Teams", data=teams_played,ax=ax1,palette="Set1",edgecolor=(0,0,0),linewidth=2)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right",fontsize=25)
plt.tight_layout()
plt.xlabel("Ipl Teams",fontfamily="Times New Roman",fontsize=25,color="Red")
plt.ylabel("No. of matches played",fontfamily="Times New Roman",fontsize=25,color="Blue")
plt.show()
# Out:
# Teams
# Mumbai Indians                 187
# Royal Challengers Bangalore    180
# Kolkata Knight Riders          178
# Kings XI Punjab                176
# Chennai Super Kings            164
# Delhi Daredevils               161
# Rajasthan Royals               147
# Sunrisers Hyderabad            108
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiants         30
# Delhi Capitals                  16
# Kochi Tuskers Kerala            14
# dtype: int64

# %%
total_count = count.to_frame().reset_index()
win_count  = win_count.to_frame().reset_index()

# %%
total_count
# Out:
#                           Teams    0
# 0                Mumbai Indians  187
# 1   Royal Challengers Bangalore  180
# 2         Kolkata Knight Riders  178
# 3               Kings XI Punjab  176
# 4           Chennai Super Kings  164
# 5              Delhi Daredevils  161
# 6              Rajasthan Royals  147
# 7           Sunrisers Hyderabad  108
# 8               Deccan Chargers   75
# 9                 Pune Warriors   46
# 10                Gujarat Lions   30
# 11               Delhi Capitals   16
# 12       Rising Pune Supergiant   16
# 13         Kochi Tuskers Kerala   14
# 14      Rising Pune Supergiants   14

# %%
win_count["winner"]
# Out:
# 0     109
# 1     100
# 2      92
# 3      84
# 4      82
# 5      75
# 6      67
# 7      58
# 8      29
# 9      15
# 10     13
# 11     12
# 12     10
# 13      6
# 14      4
# Name: winner, dtype: int64

# %%
Count_data = pd.concat([total_count,win_count["winner"]],axis=1)
Count_data.rename(columns={0:"Total_Count","winner":"Win_Counts"},inplace=True)
Count_data.fillna(0)
# Out:
#                           Teams  Total_Count  Win_Counts
# 0                Mumbai Indians          187         109
# 1   Royal Challengers Bangalore          180         100
# 2         Kolkata Knight Riders          178          92
# 3               Kings XI Punjab          176          84
# 4           Chennai Super Kings          164          82
# 5              Delhi Daredevils          161          75
# 6              Rajasthan Royals          147          67
# 7           Sunrisers Hyderabad          108          58
# 8               Deccan Chargers           75          29
# 9                 Pune Warriors           46          15
# 10                Gujarat Lions           30          13
# 11               Delhi Capitals           16          12
# 12       Rising Pune Supergiant           16          10
# 13         Kochi Tuskers Kerala           14           6
# 14      Rising Pune Supergiants           14           4

# %%
Count_data["loss_count"] = Count_data.Total_Count - Count_data.Win_Counts
Count_data
# Out:
#                           Teams  Total_Count  Win_Counts  loss_count
# 0                Mumbai Indians          187         109          78
# 1   Royal Challengers Bangalore          180         100          80
# 2         Kolkata Knight Riders          178          92          86
# 3               Kings XI Punjab          176          84          92
# 4           Chennai Super Kings          164          82          82
# 5              Delhi Daredevils          161          75          86
# 6              Rajasthan Royals          147          67          80
# 7           Sunrisers Hyderabad          108          58          50
# 8               Deccan Chargers           75          29          46
# 9                 Pune Warriors           46          15          31
# 10                Gujarat Lions           30          13          17
# 11               Delhi Capitals           16          12           4
# 12       Rising Pune Supergiant           16          10           6
# ...

# %% [markdown]
# <br>
#
# # Analysis of Deliveries
#
# <br>

# %%
df_2.head(20)
# Out:
#     match_id  inning         batting_team                 bowling_team  over  \
# 0          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 8          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 9          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 10         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# ...

# %%
df_2.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df_2.shape
# Out:
# (179078, 21)

# %% [markdown]
# ## Handling Missing values in df_2

# %%
df_2.isnull().sum().sort_values(ascending=False)
# Out:
# fielder             172630
# player_dismissed    170244
# dismissal_kind      170244
# bowler                   0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# wide_runs                0
# is_super_over            0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# match_id                 0
# dtype: int64

# %%
df_2.fillna("Not Out",inplace=True)
df_2.isnull().sum()
# Out:
# match_id            0
# inning              0
# batting_team        0
# bowling_team        0
# over                0
# ball                0
# batsman             0
# non_striker         0
# bowler              0
# is_super_over       0
# wide_runs           0
# bye_runs            0
# legbye_runs         0
# noball_runs         0
# penalty_runs        0
# batsman_runs        0
# extra_runs          0
# total_runs          0
# player_dismissed    0
# dismissal_kind      0
# fielder             0
# dtype: int64

# %%
df_2.corr()
# Out:
#                match_id    inning      over      ball  is_super_over  \
# match_id       1.000000  0.003958  0.008268 -0.001349      -0.009150
# inning         0.003958  1.000000 -0.050076 -0.003943       0.084154
# over           0.008268 -0.050076  1.000000 -0.007424      -0.034329
# ball          -0.001349 -0.003943 -0.007424  1.000000      -0.001143
# is_super_over -0.009150  0.084154 -0.034329 -0.001143       1.000000
# wide_runs     -0.007549  0.001201 -0.010003 -0.004665      -0.001019
# bye_runs       0.000905 -0.000757  0.012111  0.006602       0.001353
# legbye_runs   -0.012429 -0.001996 -0.004764 -0.002727       0.001735
# noball_runs   -0.004623 -0.000904  0.016984  0.000567       0.013640
# penalty_runs  -0.001475  0.003442 -0.000979  0.000711      -0.000071
# batsman_runs   0.033510 -0.005362  0.086701  0.007950       0.010125
# extra_runs    -0.013323 -0.000531 -0.002479 -0.002576       0.003504
# total_runs     0.030727 -0.005485  0.086326  0.007414       0.010891
#
# ...

# %% [markdown]
# ## Four Count

# %%
Fours_Count = df_2.total_runs[df_2.total_runs==4].value_counts()

# %%
Fours_Count
# Out:
# 4    20599
# Name: total_runs, dtype: int64

# %% [markdown]
# ## Six Count

# %%
Six_Count = df_2.total_runs[df_2.total_runs==6].value_counts()

# %%
Six_Count
# Out:
# 6    8148
# Name: total_runs, dtype: int64

# %% [markdown]
# ## Total Runs from 2008 to 2019 seasons

# %%
Total_runs = df_2["total_runs"].sum()
Total_runs
# Out:
# 235290

# %% [markdown]
# ## Analysing Dismissal Kind

# %%
x = df_2.groupby("dismissal_kind")["bowler"].count()

# %%
print(df_2.dismissal_kind.value_counts().sort_values(ascending=False))
plt.figure(figsize=(25,16))
sns.countplot("dismissal_kind",data=df_2)
# Out:
# Not Out                  170244
# caught                     5348
# bowled                     1581
# run out                     852
# lbw                         540
# stumped                     278
# caught and bowled           211
# retired hurt                 12
# hit wicket                   10
# obstructing the field         2
# Name: dismissal_kind, dtype: int64
# C:\Users\Sebin James\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='dismissal_kind', ylabel='count'>

# %% [markdown]
#  **No. of Balls delivered by individual Bowlers**

# %%
bowler_Count = df_2["bowler"].value_counts().sort_values(ascending=False)
bowler_Count
# Out:
# Harbhajan Singh    3451
# A Mishra           3172
# PP Chawla          3157
# R Ashwin           3016
# SL Malinga         2974
#                    ...
# C Ganapathy           6
# P Prasanth            6
# SPD Smith             2
# SN Khan               2
# AC Gilchrist          1
# Name: bowler, Length: 405, dtype: int64

# %%
df_2.bowler[df_2.bowler=="Yuvraj Singh"].value_counts()
# Out:
# Yuvraj Singh    882
# Name: bowler, dtype: int64

# %%
y = df_2.dismissal_kind.value_counts()
y
# Out:
# Not Out                  170244
# caught                     5348
# bowled                     1581
# run out                     852
# lbw                         540
# stumped                     278
# caught and bowled           211
# retired hurt                 12
# hit wicket                   10
# obstructing the field         2
# Name: dismissal_kind, dtype: int64

# %%
df_2
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
df_2["is_super_over"].value_counts()
# Out:
# 0    178997
# 1        81
# Name: is_super_over, dtype: int64

# %%
Out_by_Bowlers = df_2.bowler.groupby(df_2.dismissal_kind).value_counts().reset_index(name='Count')

# %%
Out_by_Bowlers
# Out:
#      dismissal_kind           bowler  Count
# 0           Not Out  Harbhajan Singh   3290
# 1           Not Out         A Mishra   3007
# 2           Not Out        PP Chawla   3001
# 3           Not Out         R Ashwin   2878
# 4           Not Out       SL Malinga   2786
# ...             ...              ...    ...
# 1576        stumped         T Shamsi      1
# 1577        stumped       TM Dilshan      1
# 1578        stumped          TM Head      1
# 1579        stumped         V Sehwag      1
# 1580        stumped       WPUJC Vaas      1
#
# [1581 rows x 3 columns]

# %% [markdown]
# ## Scoring Batsmen

# %%
batsmen = df_2.groupby('batsman').apply(lambda x : np.sum(x['batsman_runs'])).reset_index(name='Runs')
batsmen_sorted=batsmen.sort_values(by='Runs',ascending=False)
batsmen_sorted
# Out:
#          batsman  Runs
# 486      V Kohli  5434
# 428     SK Raina  5415
# 367    RG Sharma  4914
# 112    DA Warner  4741
# 392     S Dhawan  4632
# ..           ...   ...
# 172    IC Pandey     0
# 182      J Denly     0
# 326        P Raj     0
# 463  Sunny Gupta     0
# 235     L Ablish     0
#
# [516 rows x 2 columns]

# %%
#Top 10 Scoring Batsmen :
top_10_batsmen = batsmen_sorted[:10].sort_values(by="Runs",ascending=False)
top_10_batsmen
# Out:
#             batsman  Runs
# 486         V Kohli  5434
# 428        SK Raina  5415
# 367       RG Sharma  4914
# 112       DA Warner  4741
# 392        S Dhawan  4632
# 92         CH Gayle  4560
# 290        MS Dhoni  4477
# 384      RV Uthappa  4446
# 26   AB de Villiers  4428
# 147       G Gambhir  4223

# %%
print(top_10_batsmen)

plt.figure(figsize=(25,10))
plt.title('Top 10 Batsmen',fontsize=20)
plt.xticks(fontsize=14)
sns.set_style('dark')
sns.barplot(top_10_batsmen['batsman'],top_10_batsmen['Runs'],edgecolor=(0,0,0),linewidth=2);
# Out:
#             batsman  Runs
# 486         V Kohli  5434
# 428        SK Raina  5415
# 367       RG Sharma  4914
# 112       DA Warner  4741
# 392        S Dhawan  4632
# 92         CH Gayle  4560
# 290        MS Dhoni  4477
# 384      RV Uthappa  4446
# 26   AB de Villiers  4428
# 147       G Gambhir  4223
# C:\Users\Sebin James\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # INFERENCES FROM IPL DATA ANALYSIS
#
# ###  1.Mumbai was the city were most matches were played, next comes Kolkata and the least played city was Biomfontein
# <br>
#
# ###  2. Eden Gardens and Wankhede stadium hosted most the ipl matches
# <br>
#
# ###  3. We can see that the teams such as Mumbai Indians ,Kolkata Night Riders and Chennai Super Kings won most of the games in their home ground
# <br>
#
# ###  4. Top winning teams are Mumbai Indians, CSK, Kolkata Night Riders and the team with least win score is Kochi tuskers Kerala as they played only 2 seasons
# <br>
#
# ###  5. Most Teams who won chose to field many times than to Bat, RCB and KKR were the teams who chose to field the most
# <br>
#
# ###  6. Winning the toss increased the chance of winning of a team by 2.6%
# <br>
#
# ### 7. Chris Gayle was Man of the Match 21 times followed by ABD Villiers 20 times
# <br>
#
# ### 8. Most Games That a team played was 187 (MI) followed by 180 (RCB)
# <br>
#
# ### 9. Comparing to the number of matches each team played and won or lost King XI Punjab has the highest loss count ( 92 ) than winning count ( 84 ) out of 176 matches they played
# <br>
#
# ### 10.  Most dismissals were by catching the ball ( 5348) followed by bowled out(1581), then run out (852)
# <br>
#
# ### 11. In total there were 81 super overs played
# <br>
#
# ### 12. Virat Kohli was the top scorer batsman followed by Raina and Rohit Sharma, 7 out of top 10 batsmen were Indians
